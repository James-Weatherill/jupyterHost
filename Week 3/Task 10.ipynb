# %%
num = 0
while num <= 100:
    print("4 x", str(num).zfill(3), "=", (4 * num))
    num += 1
# Out:
# 4 x 000 = 0
# 4 x 001 = 4
# 4 x 002 = 8
# 4 x 003 = 12
# 4 x 004 = 16
# 4 x 005 = 20
# 4 x 006 = 24
# 4 x 007 = 28
# 4 x 008 = 32
# 4 x 009 = 36
# 4 x 010 = 40
# 4 x 011 = 44
# 4 x 012 = 48
# 4 x 013 = 52
# 4 x 014 = 56
# 4 x 015 = 60
# 4 x 016 = 64
# 4 x 017 = 68
# 4 x 018 = 72
# 4 x 019 = 76
# 4 x 020 = 80
# 4 x 021 = 84
# 4 x 022 = 88
# 4 x 023 = 92
# 4 x 024 = 96
# 4 x 025 = 100
# 4 x 026 = 104
# 4 x 027 = 108
# 4 x 028 = 112
# 4 x 029 = 116
# 4 x 030 = 120
# 4 x 031 = 124
# 4 x 032 = 128
# 4 x 033 = 132
# 4 x 034 = 136
# 4 x 035 = 140
# 4 x 036 = 144
# 4 x 037 = 148
# 4 x 038 = 152
# 4 x 039 = 156
# 4 x 040 = 160
# 4 x 041 = 164
# 4 x 042 = 168
# 4 x 043 = 172
# 4 x 044 = 176
# 4 x 045 = 180
# 4 x 046 = 184
# 4 x 047 = 188
# 4 x 048 = 192
# 4 x 049 = 196
# 4 x 050 = 200
# 4 x 051 = 204
# 4 x 052 = 208
# 4 x 053 = 212
# 4 x 054 = 216
# 4 x 055 = 220
# 4 x 056 = 224
# 4 x 057 = 228
# 4 x 058 = 232
# 4 x 059 = 236
# 4 x 060 = 240
# 4 x 061 = 244
# 4 x 062 = 248
# 4 x 063 = 252
# ...
