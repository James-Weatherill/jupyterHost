# %%
print("Below you will enter two numbers.\nAfter, you will have a choice of operator that you want to apply to them!\n")

def calc():

    numList = list(range(1,7))

    num1 = input("Please type your first number  : ")
    num2 = input("Please type your second number : ")
    
    if not num1.isnumeric() or not num2.isnumeric():
        calc()

    print("\nYou now have two numbers: " + str(num1) + " and " + str(num2) + ", in that order!")

#     print("""Please type the number for the operator you want, using the menu below:

#     1: Addition
#     2: Subtraction
#     3: Division
#     4: Multiplication
#     5: Power 'x'
#     6: Squared""")

    usrOp = input("""
Please type the symbol for operation you would like to perform from the list below:
Addition (+)
Subtraction (-)
Division (/)
Multiplication (*)
Power (x) -> type the power you want
Squared -> type: '^2'

Enter choice here: """)
    
    op = 0
    if usrOp == '+':
        op = 1
    elif usrOp == '-':
        op = 2
    elif usrOp == '/':
        op = 3
    elif usrOp == '*':
        op = 4
    elif usrOp.isnumeric():
        op = 5
    elif usrOp == '^2':
        op = 6

    if int(op) not in numList:
        print("Not an option, try again!")
    
    if int(op) == 1:
        print(int(num1)+int(num2))
    elif int(op) == 2:
        print(int(num1)-int(num2))
    elif int(op) == 3:
        print(int(num1)/int(num2))
    elif int(op) == 4:
        print(int(num1)*int(num2))
    elif int(op) == 5:
        i = 0
        while i < 1:
            oneOrTwo1 = input("""Which number would you like to use?: 
1: First Number
2: Second Number

Enter choice here: """)
            if int(oneOrTwo1) == 1:
                print(int(num1)**int(usrOp))
                i += 1
            elif int(oneOrTwo1) == 2:
                print(int(num2)**int(usrOp))
                i += 1
            else:
                print(oneOrTwo1 + " is not an option. Try again")
    else:
        l = 0
        while l < 1:
            oneOrTwo2 = input("""Which number would you like to use?: 
1: First Number
2: Second Number

Enter choice here: """)
            if int(oneOrTwo2) == 1:
                print(int(num1)**2)
                l += 1
            elif int(oneOrTwo2) == 2:
                print(int(num2)**2)
                l += 1
            else:
                print(oenOrTwo2 + " is not an option. Try again")
                
calc()
# Out:
# Below you will enter two numbers.
# After, you will have a choice of operator that you want to apply to them!
#
# Please type your first number  : 5
# Please type your second number : 16
#
# You now have two numbers: 5 and 16, in that order!
#
# Please type the symbol for operation you would like to perform from the list below:
# Addition (+)
# Subtraction (-)
# Division (/)
# Multiplication (*)
# Power (x) -> type the power you want
# Squared -> type: '^2'
#
# Enter choice here: 4
# Which number would you like to use?:
# 1: First Number
# 2: Second Number
#
# Enter choice here: 2
# 65536
