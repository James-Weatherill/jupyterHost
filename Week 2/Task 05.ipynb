# %%
print("Below you will enter two numbers.\nAfter, you will have a choice of operator that you want to apply to them!")

def calc():

    numList = list(range(1,7))

    num1 = input("Please type your first number  : ")
    num2 = input("Please type your second number : ")
    
    if not num1.isnumeric() or not num2.isnumeric():
        calc()

    print("You now have two numbers: " + str(num1) + " and " + str(num2) + ", in that order!")

    print("""Please type the number for the operator you want, using the menu below:

    1: Addition
    2: Subtraction
    3: Division
    4: Multiplication
    5: Power 'x'
    6: Squared""")

    op = input("\nEnter choice here: ")

    if int(op) not in numList:
        print("Not an option, try again!")
    
    if int(op) == 1:
        print(int(num1)+int(num2))
    elif int(op) == 2:
        print(int(num1)-int(num2))
    elif int(op) == 3:
        print(int(num1)/int(num2))
    elif int(op) == 4:
        print(int(num1)*int(num2))
    elif int(op) == 5:
        i = 0
        while i < 1:
            oneOrTwo1 = input("""Which number would you like to use?: 
1: First Number
2: Second Number

Enter choice here: """)
            if int(oneOrTwo1) == 1:
                j = 0
                while j < 1:
                    power1 = input("What power would you like to raise this to?: ")
                    if power1.isnumeric():
                        print(int(num1)**int(power1))
                        j += 1
                        i += 1  
                    else:
                        print("Invalid, try an integer.")
            elif int(oneOrTwo1) == 2:
                k = 0
                while k < 1:
                    power2 = input("What power would you like to raise this to?: ")
                    if power2.isnumeric():
                        print(int(num2)**int(power2))
                        k += 1
                        i += 1
                    else:
                        print("Invalid, try an integer.")
            else:
                print(oneOrTwo1 + " is not an option. Try again")
    else:
        l = 0
        while l < 1:
            oneOrTwo2 = input("""Which number would you like to use?: 
1: First Number
2: Second Number

Enter choice here: """)
            if int(oneOrTwo2) == 1:
                print(int(num1)**2)
                l += 1
            elif int(oneOrTwo2) == 2:
                print(int(num2)**2)
                l += 1
            else:
                print(oenOrTwo2 + " is not an option. Try again")
                
calc()
# Out:
# Below you will enter two numbers.
# After, you will have a choice of operator that you want to apply to them!
# Please type your first number  : 50
# Please type your second number : 702
# You now have two numbers: 50 and 702, in that order!
# Please type the number for the operator you want, using the menu below:
#
#     1: Addition
#     2: Subtraction
#     3: Division
#     4: Multiplication
#     5: Power 'x'
#     6: Squared
#
# Enter choice here: 1
# 752
